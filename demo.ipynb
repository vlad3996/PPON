# %%
from inference_utils import load_netG, infer_single_image, show_plot
from skimage import io 
import matplotlib.pyplot as plt
# %matplotlib inline

device = 'cpu'
checkpoint_path = './checkpoints/PPON_G.pth'

model = load_netG(checkpoint_path, device)
img_path = './Test_Datasets/Set5_LR/woman.bmp'
img = io.imread(img_path)
out_c, out_s, out_p = infer_single_image(model, img, device)


show_plot(img, out_c, out_s, out_p)

# %%
# import cv2
# cv2.imwrite('SR_out.jpg', cv2.cvtColor(out_p, cv2.COLOR_RGB2BGR))
